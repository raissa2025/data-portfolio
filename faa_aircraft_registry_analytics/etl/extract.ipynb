# %%
import pandas as pd

# Import data
df1=pd.read_csv(MASTER.txt)
df2=pd.read_csv(ACFTREF.txt)

## Save  raw data
df1.to_csv("master_raw.csv", index=False)
df2.to_csv("reference_raw.csv", index=False)
